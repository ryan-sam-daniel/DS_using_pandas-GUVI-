# %%
import pandas as pd

# %%
df = pd.read_csv("E:\Guvi\pandas_course\data\sales_information.csv")

# %%
df[["Country", "Region"]]
# Out:
#       Country Region
# 0       India  North
# 1          US  North
# 2          UK  North
# 3   Australia   East
# 4      Africa   East
# 5   Singapore   East
# 6     Mylasia   West
# 7       India   West
# 8          US   West
# 9          UK  North
# 10  Australia  North
# 11     Africa  North
# 12  Singapore   East
# 13    Mylasia   East
# 14      India   East
# 15         US   West
# 16         UK   West
# 17  Australia   West
# 18     Africa  North
# 19  Singapore  North

# %%
selected_column=["Country", "Region"]
df[selected_column]
# Out:
#       Country Region
# 0       India  North
# 1          US  North
# 2          UK  North
# 3   Australia   East
# 4      Africa   East
# 5   Singapore   East
# 6     Mylasia   West
# 7       India   West
# 8          US   West
# 9          UK  North
# 10  Australia  North
# 11     Africa  North
# 12  Singapore   East
# 13    Mylasia   East
# 14      India   East
# 15         US   West
# 16         UK   West
# 17  Australia   West
# 18     Africa  North
# 19  Singapore  North

# %%
df.iloc[0:3]  #iloc=index
# Out:
#   Country Region Sales Person   Date of Purchase   Total  Quantity
# 0   India  North         John  8/20/2012 0:00:00  100000       567
# 1      US  North         Bill  9/15/2014 0:00:00  120000      3000
# 2      UK  North       Thomas  6/19/2011 0:00:00  140000       345

# %%
df[(df["Country"] == "India") & (df["Quantity"] > 90)]
# Out:
#   Country Region Sales Person   Date of Purchase   Total  Quantity
# 0   India  North         John  8/20/2012 0:00:00  100000       567
# 7   India   West         Bill  1/24/2014 0:00:00  240000       200

# %%
calls_made = [10] * 10 + [60] * 10
calls_made
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60]

# %%
df["Calls_Made"]= calls_made
df.tail()
# Out:
#       Country Region Sales Person    Date of Purchase   Total  Quantity  \
# 15         US   West         John  12/31/2013 0:00:00  220000        90
# 16         UK   West         Bill    3/6/2015 0:00:00  240000        90
# 17  Australia   West       Thomas   5/12/2014 0:00:00  260000        90
# 18     Africa  North         John    2/8/2018 0:00:00  140000        85
# 19  Singapore  North         Bill   12/1/2016 0:00:00  150000        85
#
#     Calls_Made
# 15          60
# 16          60
# 17          60
# 18          60
# 19          60

# %%
row=["China", "East" , "Jim" , "12/1/2016 0:00:00"	, "70000", "40", "60"]

# %%
new_df_row=pd.DataFrame([row], columns=df.columns.values)

# %%
df._append(new_df_row,ignore_index=True)
# Out:
#       Country Region Sales Person    Date of Purchase     Total Quantity  \
# 0       India  North         John   8/20/2012 0:00:00    100000      567
# 1          US  North         Bill   9/15/2014 0:00:00    120000     3000
# 2          UK  North       Thomas   6/19/2011 0:00:00    140000      345
# 3   Australia   East         John  11/11/2013 0:00:00    160000     1000
# 4      Africa   East         Bill   6/14/2013 0:00:00    180000      123
# 5   Singapore   East       Thomas  12/23/2017 0:00:00    200000     1000
# 6     Mylasia   West         John   3/19/2015 0:00:00   1000000     7890
# 7       India   West         Bill   1/24/2014 0:00:00    240000      200
# 8          US   West       Thomas   4/27/2012 0:00:00  26000000     1000
# 9          UK  North         John    3/7/2011 0:00:00    100000     1000
# 10  Australia  North         Bill  10/14/2013 0:00:00    120000      567
# 11     Africa  North       Thomas    1/5/2011 0:00:00    140000     1000
# ...

# %%
po_numbers=[ int(f"1000{i}") for i in range(20)]
import random
random.shuffle(po_numbers)
po_numbers
# Out:
# [10001,
#  100015,
#  100019,
#  100016,
#  100011,
#  10002,
#  100010,
#  10003,
#  100014,
#  100013,
#  10000,
#  10006,
#  10007,
#  100018,
#  10009,
#  10008,
#  10004,
#  100012,
#  100017,
#  10005]

# %%
df["PONumber"]=po_numbers
df.set_index("PONumber", inplace=True)

# %%
df.sort_values(["Country","Region"], inplace=True)

# %%
df.head()
# Out:
#             Country Region Sales Person    Date of Purchase   Total  Quantity  \
# PONumber
# 100011       Africa   East         Bill   6/14/2013 0:00:00  180000       123
# 10006        Africa  North       Thomas    1/5/2011 0:00:00  140000      1000
# 100017       Africa  North         John    2/8/2018 0:00:00  140000        85
# 100016    Australia   East         John  11/11/2013 0:00:00  160000      1000
# 10000     Australia  North         Bill  10/14/2013 0:00:00  120000       567
#
#           Calls_Made
# PONumber
# 100011            10
# 10006             60
# 100017            60
# 100016            10
# 10000             60

# %%
df["Date of Purchase"]=pd.to_datetime(df["Date of Purchase"])

# %%
df["Year"]=df["Date of Purchase"].dt.year

# %%
df[["Total","Quantity"]].min()
# Out:
# Total       100000
# Quantity        85
# dtype: int64

# %%
df.min()
# Out:
# Country                          Africa
# Region                             East
# Sales Person                       Bill
# Date of Purchase    2011-01-05 00:00:00
# Total                            100000
# Quantity                             85
# Calls_Made                           10
# Year                               2011
# dtype: object

# %%
df["Sales Person"][df["Total"] == df["Total"].max()]
# Out:
# PONumber
# 100014    Thomas
# Name: Sales Person, dtype: object

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 df.corr()
#
# File E:\Guvi\pandas_course\pandas_venv\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File E:\Guvi\pandas_course\pandas_venv\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...
